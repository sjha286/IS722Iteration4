# %%
import findspark
findspark.init('/home/ubuntu/spark-2.1.1-bin-hadoop2.7')
import pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('Step 3 Data Preparation').getOrCreate()

# %%
df = spark.read.csv('Department 11 Field Interviews.csv', header=True, inferSchema=True)

# %% [markdown]
# <b>3.1</b><br/>
# The columns have to be renamed

# %%
from functools import reduce

# %%
old_col = df.schema.names #original column headings
new_col = [i for i in df.head(1)[0]] #new column headings
df = reduce(lambda df, idx: df.withColumnRenamed(old_col[idx], new_col[idx]), range(len(old_col)), df) #replace with lambda function

# %% [markdown]
# Now the first row is the same as the header, and can be dropped using 'where' clause

# %%
df = df.where("SEQ_NUM != 'SEQ_NUM'")

# %% [markdown]
# Now we can drop unneccesary fields

# %%
df = df[['SEX', 'PRIORS', 'DESCRIPTION', 'COMPLEXION', 'FIOFS_TYPE', 'TERRORISM', 'SEARCH', 'BASIS', 'STOP_REASONS', 'FIOFS_REASONS',
         'OUTCOME', 'VEH_OCCUPANT', 'ETHNICITY', 'AGE_AT_FIO_CORRECTED']]

# %%
df.show(5)
# Out:
# +----+------+-----------+----------+----------+---------+------+--------------------+---------------+--------------------+-------+------------+---------+--------------------+
# | SEX|PRIORS|DESCRIPTION|COMPLEXION|FIOFS_TYPE|TERRORISM|SEARCH|               BASIS|   STOP_REASONS|       FIOFS_REASONS|OUTCOME|VEH_OCCUPANT|ETHNICITY|AGE_AT_FIO_CORRECTED|
# +----+------+-----------+----------+----------+---------+------+--------------------+---------------+--------------------+-------+------------+---------+--------------------+
# |MALE|   YES|   B(Black)|       Med|      IOFS|       NO|    VP|      CONSENT SEARCH|  INVESTIGATIVE|DRUGS, INVESTIGATION|    SFO|      DRIVER|     null|                  59|
# |MALE|    NO|   W(White)|       Med|        IO|       NO|  null|REASONABLE SUSPICION|     RADIO CALL|   DRUGS, POSSESSION|      F|        null|     null|                  26|
# |MALE|   YES|   B(Black)|      Dark|       IOF|       NO|  null|                null|OTHER (SPECIFY)| INVESTIGATE, PERSON|      F|        null|     null|                  18|
# |MALE|   YES|   B(Black)|       Med|      IOFS|       NO|  null|                null|  INVESTIGATIVE|                ABDW|      S|        null|     null|                  24|
# |MALE|   YES|   B(Black)|     Light|        IO|       NO|     P|REASONABLE SUSPICION|  INVESTIGATIVE|                 VAL|      F|        null|     null|                  70|
# +----+------+-----------+----------+----------+---------+------+--------------------+---------------+--------------------+-------+------------+---------+--------------------+
# only showing top 5 rows

# %% [markdown]
# 3.1 is repeated for the second dataset.

# %%
df2 = spark.read.csv('Department 24 Vehicle Stops.csv', header=True, inferSchema=True)

# %%
old_col = df2.schema.names #original column headings
new_col = [i for i in df2.head(1)[0]] #new column headings
df2 = reduce(lambda df2, idx: df2.withColumnRenamed(old_col[idx], new_col[idx]), range(len(old_col)), df2) #replace with lambda function

# %%
df2 = df2[df2['YEAR OF STOP'] != 'YEAR OF STOP']

# %%
df2 = df2[['RACE OF DRIVER', 'GENDER OF DRIVER', 'DRIVER FRISKED?', 'VEHICLE SEARCHED?', 'CITATION ISSUED?', 'AGE OF DRIVER', 
           'REASON FOR STOP']]

# %%
df2.show(5)
# Out:
# +--------------+----------------+---------------+-----------------+----------------+-------------+---------------+
# |RACE OF DRIVER|GENDER OF DRIVER|DRIVER FRISKED?|VEHICLE SEARCHED?|CITATION ISSUED?|AGE OF DRIVER|REASON FOR STOP|
# +--------------+----------------+---------------+-----------------+----------------+-------------+---------------+
# |         White|          Female|             No|               No|              No|         null|        No Data|
# |         White|            Male|             No|               No|              No|         null|        No Data|
# |         White|            Male|             No|               No|              No|         null|        No Data|
# |         White|            Male|             No|               No|              No|         null|        No Data|
# |         Asian|          Female|            Yes|               No|              No|         null|        No Data|
# +--------------+----------------+---------------+-----------------+----------------+-------------+---------------+
# only showing top 5 rows

# %% [markdown]
# <b>3.2</b><br/>
# First we replace all codes for null values with NoneType

# %%
from pyspark.sql.functions import when, count

# %%
missing_values = ["UNKNOWN", "NO DATA ENTERED", -1, "No Data"]
for i in missing_values:
    for j in df.columns: #go through all columns to replace codes with null
        df = df.withColumn(j, when(df[j] == i, None).otherwise(df[j]))
    for j in df2.columns: #repeat for 2nd dataset
        df2 = df2.withColumn(j, when(df2[j] == i, None).otherwise(df2[j]))
df = df.withColumn("AGE_AT_FIO_CORRECTED", when(df["AGE_AT_FIO_CORRECTED"] >= 100, None).otherwise(df["AGE_AT_FIO_CORRECTED"]))
df = df.withColumn("AGE_AT_FIO_CORRECTED", when(df["AGE_AT_FIO_CORRECTED"] <= 10, None).otherwise(df["AGE_AT_FIO_CORRECTED"]))
#replace age values below 10 or over 100 with null

# %% [markdown]
# Now we will remove columns with 25% or more empty values

# %%
x = []
for c in df.columns:
    x.append((count(when(df[c].isNull(), c))*100.0/df.count()).alias(c))
col_emp = df.select(x).collect()
emp_col = [row.asDict() for row in col_emp] #store each column as key and its emptiness as value
emp_col = emp_col[0]
col_null_g_25p=[i for i in emp_col if emp_col[i] > 25]
df = df.drop(*col_null_g_25p)
df.show()
# Out:
# +----+------+-----------+----------+----------+---------+--------------------+-------+--------------------+
# | SEX|PRIORS|DESCRIPTION|COMPLEXION|FIOFS_TYPE|TERRORISM|       FIOFS_REASONS|OUTCOME|AGE_AT_FIO_CORRECTED|
# +----+------+-----------+----------+----------+---------+--------------------+-------+--------------------+
# |MALE|   YES|   B(Black)|       Med|      IOFS|       NO|DRUGS, INVESTIGATION|    SFO|                  59|
# |MALE|    NO|   W(White)|       Med|        IO|       NO|   DRUGS, POSSESSION|      F|                  26|
# |MALE|   YES|   B(Black)|      Dark|       IOF|       NO| INVESTIGATE, PERSON|      F|                  18|
# |MALE|   YES|   B(Black)|       Med|      IOFS|       NO|                ABDW|      S|                  24|
# |MALE|   YES|   B(Black)|     Light|        IO|       NO|                 VAL|      F|                  70|
# |MALE|   YES|       null|      Dark|        IO|       NO|ALCOHOL, PUBLIC D...|      F|                  51|
# |MALE|   YES|   B(Black)|       Med|       IOF|       NO| INVESTIGATE, PERSON|      F|                  30|
# |MALE|    NO|   B(Black)|       Med|        IO|       NO|                 VAL|      F|                  34|
# |MALE|   YES|   B(Black)|      null|        IO|       NO| INVESTIGATE, PERSON|      F|                  27|
# |MALE|   YES|   W(White)|     OTHER|        IO|       NO|         DISTURBANCE|      F|                  47|
# |MALE|   YES|       null|       Med|        OF|       NO| INVESTIGATE, PERSON|      F|                  26|
# |MALE|   YES|   W(White)|     OTHER|        IO|       NO| INVESTIGATE, PERSON|      F|                  39|
# |MALE|    NO|H(Hispanic)|     Light|        IO|       NO| INVESTIGATE, PERSON|      F|                  15|
# |MALE|   YES|   W(White)|       Med|         I|       NO|           209A, A&B|     SF|                  45|
# |MALE|   YES|   B(Black)|       Med|         O|       NO| INVESTIGATE, PERSON|      F|                  21|
# |MALE|  null|   B(Black)|      Dark|        IO|       NO| INVESTIGATE, PERSON|      F|                  51|
# |MALE|   YES|   B(Black)|      Dark|        OF|       NO|           209A, A&B|     SF|                  48|
# |MALE|   YES|   B(Black)|       Med|        IO|       NO| INVESTIGATE, PERSON|      F|                  19|
# |MALE|   YES|H(Hispanic)|      Dark|        IO|       NO| INVESTIGATE, PERSON|      F|                  45|
# |MALE|   YES|   B(Black)|      Dark|       IOF|       NO| INVESTIGATE, PERSON|      F|                  18|
# +----+------+-----------+----------+----------+---------+--------------------+-------+--------------------+
# only showing top 20 rows

# %%
df = df.dropna(how='any')

# %% [markdown]
# Now we repeat 3.2 for the second dataset.

# %%
x = []
for c in df2.columns:
    x.append((count(when(df2[c].isNull(), c))*100.0/df2.count()).alias(c))
col_emp = df2.select(x).collect()
emp_col = [row.asDict() for row in col_emp] #store each column as key and its emptiness as value
emp_col = emp_col[0]
col_null_g_25p=[i for i in emp_col if emp_col[i] > 25]
df2 = df2.drop(*col_null_g_25p)
df2 = df2.dropna(how='any')

# %% [markdown]
# <b>3.3<b/>

# %%
df2_ex = spark.read.csv('Department 24 Vehicle Stops.csv', header=True, inferSchema=True)

# %%
from pyspark.sql.functions import concat, lit

# %%
df2_ex = df2_ex.select("*", concat(df2_ex["LOCATION_LATITUDE"],lit(" "),df2_ex["LOCATION_LONGITUDE"]).alias("COORDINATES"))

# %%
df2_ex.select('COORDINATES').collect()
# Out:
# [Row(COORDINATES='LOCATION OF STOP LAT LOCATION OF STOP LONG'),
#  Row(COORDINATES='44.97391713 -93.06089457'),
#  Row(COORDINATES='44.95211807 -93.15173337'),
#  Row(COORDINATES='44.9738881 -93.03039075'),
#  Row(COORDINATES='44.97358832 -93.17215188'),
#  Row(COORDINATES='44.95987773 -93.06094546'),
#  Row(COORDINATES='44.9536711 -93.10112732'),
#  Row(COORDINATES='44.95934727 -93.12122586'),
#  Row(COORDINATES='44.93079234 -93.08574357'),
#  Row(COORDINATES='44.98110238 -93.02019274'),
#  Row(COORDINATES='44.95936066 -93.14154747'),
#  Row(COORDINATES='44.95916259 -93.07181545'),
#  Row(COORDINATES='44.96015434 -93.09197852'),
#  Row(COORDINATES='44.95929424 -93.16188682'),
#  Row(COORDINATES='44.95211807 -93.15173337'),
#  Row(COORDINATES='44.98475702 -93.2027105'),
#  Row(COORDINATES='44.96671118 -93.10117378'),
#  Row(COORDINATES='44.95212653 -93.13138291'),
#  Row(COORDINATES='44.94342881 -93.10668882'),
#  Row(COORDINATES='44.91613019 -93.13952579'),
#  Row(COORDINATES='44.94864046 -93.1021296'),
#  Row(COORDINATES='44.95936066 -93.14154747'),
#  Row(COORDINATES='44.97353439 -93.09250912'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.98097513 -93.11098715'),
#  Row(COORDINATES='44.9738881 -93.03039075'),
#  Row(COORDINATES='44.93062156 -93.16192932'),
#  Row(COORDINATES='44.92321274 -93.07594613'),
#  Row(COORDINATES='44.95934727 -93.12122586'),
#  Row(COORDINATES='44.96011643 -93.0412236'),
#  Row(COORDINATES='44.95934727 -93.12122586'),
#  Row(COORDINATES='44.96011643 -93.0412236'),
#  Row(COORDINATES='44.930685 -93.07629816'),
#  Row(COORDINATES='44.89857447 -93.16755296'),
#  Row(COORDINATES='44.97277532 -93.05082055'),
#  Row(COORDINATES='44.96667981 -93.06092301'),
#  Row(COORDINATES='44.96015434 -93.09197852'),
#  Row(COORDINATES='44.93079234 -93.08574357'),
#  Row(COORDINATES='44.96667981 -93.06092301'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.95991525 -93.02022928'),
#  Row(COORDINATES='44.97391713 -93.06089457'),
#  Row(COORDINATES='44.97385967 -93.07103595'),
#  Row(COORDINATES='44.93103211 -93.09519964'),
#  Row(COORDINATES='44.93834266 -93.08555629'),
#  Row(COORDINATES='44.95934727 -93.12122586'),
#  Row(COORDINATES='44.96015434 -93.09197852'),
#  Row(COORDINATES='44.930685 -93.07629816'),
#  Row(COORDINATES='44.93079234 -93.08574357'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.94864046 -93.1021296'),
#  Row(COORDINATES='44.97277532 -93.05082055'),
#  Row(COORDINATES='44.98105556 -93.07106812'),
#  Row(COORDINATES='44.96701855 -93.11083062'),
#  Row(COORDINATES='44.95934727 -93.12122586'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.94864046 -93.1021296'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.96667981 -93.06092301'),
#  Row(COORDINATES='44.97391713 -93.06089457'),
#  Row(COORDINATES='44.96673342 -93.0821136'),
#  Row(COORDINATES='44.95934727 -93.12122586'),
#  Row(COORDINATES='44.97388818 -93.02023732'),
#  Row(COORDINATES='44.94493121 -93.12116127'),
#  Row(COORDINATES='44.95211807 -93.15173337'),
#  Row(COORDINATES='44.930685 -93.07629816'),
#  Row(COORDINATES='44.930685 -93.07629816'),
#  Row(COORDINATES='44.98636717 -93.16177533'),
#  Row(COORDINATES='44.98110238 -93.02019274'),
#  Row(COORDINATES='44.9435416 -93.09742475'),
#  Row(COORDINATES='44.92934199 -93.13214946'),
#  Row(COORDINATES='44.93834266 -93.08555629'),
#  Row(COORDINATES='44.94493121 -93.12116127'),
#  Row(COORDINATES='44.98115423 -93.05070486'),
#  Row(COORDINATES='44.98111596 -93.03036805'),
#  Row(COORDINATES='44.95916259 -93.07181545'),
#  Row(COORDINATES='44.95271832 -93.02018304'),
#  Row(COORDINATES='44.98106675 -93.06120649'),
#  Row(COORDINATES='44.9161636 -93.18228368'),
#  Row(COORDINATES='44.96656139 -93.02057424'),
#  Row(COORDINATES='44.92438448 -93.06155463'),
#  Row(COORDINATES='44.96673342 -93.0821136'),
#  Row(COORDINATES='44.95950658 -93.10207704'),
#  Row(COORDINATES='44.93079234 -93.08574357'),
#  Row(COORDINATES='44.95203834 -93.17207019'),
#  Row(COORDINATES='44.98106675 -93.06120649'),
#  Row(COORDINATES='44.93788404 -93.19399087'),
#  Row(COORDINATES='44.95936066 -93.14154747'),
#  Row(COORDINATES='44.98114804 -93.0405584'),
#  Row(COORDINATES='44.93065163 -93.17211765'),
#  Row(COORDINATES='44.95934727 -93.12122586'),
#  Row(COORDINATES='44.95195822 -93.06126233'),
#  Row(COORDINATES='44.98821439 -93.08263819'),
#  Row(COORDINATES='44.96667981 -93.06092301'),
#  Row(COORDINATES='44.95203834 -93.17207019'),
#  Row(COORDINATES='44.95929424 -93.16188682'),
#  Row(COORDINATES='44.89857447 -93.16755296'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.95981363 -93.11124934'),
#  Row(COORDINATES='44.95929424 -93.16188682'),
#  Row(COORDINATES='44.93065163 -93.17211765'),
#  Row(COORDINATES='44.95206015 -93.16189808'),
#  Row(COORDINATES='44.95203834 -93.17207019'),
#  Row(COORDINATES='44.95206541 -93.11116232'),
#  Row(COORDINATES='44.95212336 -93.1415627'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.95987773 -93.06094546'),
#  Row(COORDINATES='44.95934557 -93.15171272'),
#  Row(COORDINATES='44.95206541 -93.11116232'),
#  Row(COORDINATES='44.95929424 -93.16188682'),
#  Row(COORDINATES='44.98106675 -93.06120649'),
#  Row(COORDINATES='44.94496257 -93.1415298'),
#  Row(COORDINATES='44.94630857 -93.09137717'),
#  Row(COORDINATES='44.95981363 -93.11124934'),
#  Row(COORDINATES='44.95271832 -93.02018304'),
#  Row(COORDINATES='44.95195822 -93.06126233'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.95981363 -93.11124934'),
#  Row(COORDINATES='44.92334938 -93.14159276'),
#  Row(COORDINATES='44.95212653 -93.13138291'),
#  Row(COORDINATES='44.91614709 -93.17212624'),
#  Row(COORDINATES='44.95212653 -93.13138291'),
#  Row(COORDINATES='44.9453393 -93.11134451'),
#  Row(COORDINATES='44.96663472 -93.07103166'),
#  Row(COORDINATES='44.98069554 -93.09262204'),
#  Row(COORDINATES='44.98110238 -93.02019274'),
#  Row(COORDINATES='44.96580346 -93.1831301'),
#  Row(COORDINATES='44.96580346 -93.1831301'),
#  Row(COORDINATES='44.98110238 -93.02019274'),
#  Row(COORDINATES='44.98110238 -93.02019274'),
#  Row(COORDINATES='44.96580346 -93.1831301'),
#  Row(COORDINATES='44.98110238 -93.02019274'),
#  Row(COORDINATES='44.98110238 -93.02019274'),
#  Row(COORDINATES='44.96580346 -93.1831301'),
#  Row(COORDINATES='44.98110238 -93.02019274'),
#  Row(COORDINATES='44.98110238 -93.02019274'),
#  Row(COORDINATES='44.98110238 -93.02019274'),
#  Row(COORDINATES='44.98110238 -93.02019274'),
#  Row(COORDINATES='44.95273585 -93.0427568'),
#  Row(COORDINATES='44.95206015 -93.16189808'),
#  Row(COORDINATES='44.98110238 -93.02019274'),
#  Row(COORDINATES='44.98110238 -93.02019274'),
#  Row(COORDINATES='44.96543456 -93.12229417'),
#  Row(COORDINATES='44.98110238 -93.02019274'),
#  Row(COORDINATES='44.95271832 -93.02018304'),
#  Row(COORDINATES='44.98096117 -93.08248534'),
#  Row(COORDINATES='44.98110238 -93.02019274'),
#  Row(COORDINATES='44.94081303 -93.04584707'),
#  Row(COORDINATES='44.98096117 -93.08248534'),
#  Row(COORDINATES='44.98110238 -93.02019274'),
#  Row(COORDINATES='44.95273585 -93.0427568'),
#  Row(COORDINATES='44.97367764 -93.13112479'),
#  Row(COORDINATES='44.96543456 -93.12229417'),
#  Row(COORDINATES='44.97381926 -93.10113982'),
#  Row(COORDINATES='44.92939166 -93.01210146'),
#  Row(COORDINATES='44.97367764 -93.13112479'),
#  Row(COORDINATES='44.98110238 -93.02019274'),
#  Row(COORDINATES='44.98115423 -93.05070486'),
#  Row(COORDINATES='44.98821265 -93.10115556'),
#  Row(COORDINATES='44.98819579 -93.11092818'),
#  Row(COORDINATES='44.95271832 -93.02018304'),
#  Row(COORDINATES='44.97378009 -93.12120869'),
#  Row(COORDINATES='44.96663472 -93.07103166'),
#  Row(COORDINATES='44.97378009 -93.12120869'),
#  Row(COORDINATES='44.96663472 -93.07103166'),
#  Row(COORDINATES='44.98069554 -93.09262204'),
#  Row(COORDINATES='44.97378009 -93.12120869'),
#  Row(COORDINATES='44.97378009 -93.12120869'),
#  Row(COORDINATES='44.96663472 -93.07103166'),
#  Row(COORDINATES='44.97378009 -93.12120869'),
#  Row(COORDINATES='44.95934727 -93.12122586'),
#  Row(COORDINATES='44.97385967 -93.07103595'),
#  Row(COORDINATES='44.94011645 -93.02768683'),
#  Row(COORDINATES='44.98096117 -93.08248534'),
#  Row(COORDINATES='44.94630857 -93.09137717'),
#  Row(COORDINATES='44.98097513 -93.11098715'),
#  Row(COORDINATES='44.9809914 -93.10114494'),
#  Row(COORDINATES='44.97378969 -93.11103459'),
#  Row(COORDINATES='44.97378969 -93.11103459'),
#  Row(COORDINATES='44.98097513 -93.11098715'),
#  Row(COORDINATES='44.97381926 -93.10113982'),
#  Row(COORDINATES='44.97378969 -93.11103459'),
#  Row(COORDINATES='44.9809914 -93.10114494'),
#  Row(COORDINATES='44.97378969 -93.11103459'),
#  Row(COORDINATES='44.98110238 -93.02019274'),
#  Row(COORDINATES='44.96048735 -93.08086542'),
#  Row(COORDINATES='44.98097513 -93.11098715'),
#  Row(COORDINATES='44.95936066 -93.14154747'),
#  Row(COORDINATES='44.96015434 -93.09197852'),
#  Row(COORDINATES='44.98097513 -93.11098715'),
#  Row(COORDINATES='44.98097513 -93.11098715'),
#  Row(COORDINATES='44.94864046 -93.1021296'),
#  Row(COORDINATES='44.98069554 -93.09262204'),
#  Row(COORDINATES='44.9809914 -93.10114494'),
#  Row(COORDINATES='44.94493698 -93.13135062'),
#  Row(COORDINATES='44.96048735 -93.08086542'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.98097513 -93.11098715'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.98106675 -93.06120649'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.95916259 -93.07181545'),
#  Row(COORDINATES='44.95950658 -93.10207704'),
#  Row(COORDINATES='44.95916259 -93.07181545'),
#  Row(COORDINATES='44.98821265 -93.10115556'),
#  Row(COORDINATES='44.96580346 -93.1831301'),
#  Row(COORDINATES='44.94492909 -93.17207404'),
#  Row(COORDINATES='44.95934557 -93.15171272'),
#  Row(COORDINATES='44.94496257 -93.1415298'),
#  Row(COORDINATES='44.96580346 -93.1831301'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.92340119 -93.17209879'),
#  Row(COORDINATES='44.96654212 -93.1933639'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.95195822 -93.06126233'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.98115423 -93.05070486'),
#  Row(COORDINATES='44.98105556 -93.07106812'),
#  Row(COORDINATES='44.95981363 -93.11124934'),
#  Row(COORDINATES='44.96684449 -93.15174239'),
#  Row(COORDINATES='44.96575731 -93.05016568'),
#  Row(COORDINATES='44.96663472 -93.07103166'),
#  Row(COORDINATES='44.98115423 -93.05070486'),
#  Row(COORDINATES='44.98097513 -93.11098715'),
#  Row(COORDINATES='44.95916259 -93.07181545'),
#  Row(COORDINATES='44.96575731 -93.05016568'),
#  Row(COORDINATES='44.96667981 -93.06092301'),
#  Row(COORDINATES='44.96637056 -93.17209931'),
#  Row(COORDINATES='44.97374807 -93.08236551'),
#  Row(COORDINATES='44.96656139 -93.02057424'),
#  Row(COORDINATES='44.93079234 -93.08574357'),
#  Row(COORDINATES='44.94079035 -93.07635844'),
#  Row(COORDINATES='44.95929424 -93.16188682'),
#  Row(COORDINATES='44.95936066 -93.14154747'),
#  Row(COORDINATES='44.98096117 -93.08248534'),
#  Row(COORDINATES='44.96580346 -93.1831301'),
#  Row(COORDINATES='44.98115423 -93.05070486'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.95195822 -93.06126233'),
#  Row(COORDINATES='44.97388818 -93.02023732'),
#  Row(COORDINATES='44.96717237 -93.16189329'),
#  Row(COORDINATES='44.94496532 -93.15172774'),
#  Row(COORDINATES='44.93072809 -93.19383946'),
#  Row(COORDINATES='44.93103211 -93.09519964'),
#  Row(COORDINATES='44.93788404 -93.19399087'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.97385967 -93.07103595'),
#  Row(COORDINATES='44.97374807 -93.08236551'),
#  Row(COORDINATES='44.95934727 -93.12122586'),
#  Row(COORDINATES='44.98096815 -93.12118743'),
#  Row(COORDINATES='44.95206015 -93.16189808'),
#  Row(COORDINATES='44.96033456 -93.18220895'),
#  Row(COORDINATES='44.95934727 -93.12122586'),
#  Row(COORDINATES='44.97391713 -93.06089457'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.97391713 -93.06089457'),
#  Row(COORDINATES='44.94342881 -93.10668882'),
#  Row(COORDINATES='44.98105556 -93.07106812'),
#  Row(COORDINATES='44.95936066 -93.14154747'),
#  Row(COORDINATES='44.95212653 -93.13138291'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.95271832 -93.02018304'),
#  Row(COORDINATES='44.97277532 -93.05082055'),
#  Row(COORDINATES='44.95211807 -93.15173337'),
#  Row(COORDINATES='44.95916259 -93.07181545'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.95934557 -93.15171272'),
#  Row(COORDINATES='44.95206541 -93.11116232'),
#  Row(COORDINATES='44.95212653 -93.13138291'),
#  Row(COORDINATES='44.94493698 -93.13135062'),
#  Row(COORDINATES='44.95212653 -93.13138291'),
#  Row(COORDINATES='44.95934727 -93.12122586'),
#  Row(COORDINATES='44.95186095 -93.07246085'),
#  Row(COORDINATES='44.95490625 -93.08839557'),
#  Row(COORDINATES='44.94493698 -93.13135062'),
#  Row(COORDINATES='44.97374807 -93.08236551'),
#  Row(COORDINATES='44.95936066 -93.14154747'),
#  Row(COORDINATES='44.95934557 -93.15171272'),
#  Row(COORDINATES='44.93901459 -93.122455'),
#  Row(COORDINATES='44.95212653 -93.13138291'),
#  Row(COORDINATES='44.95212336 -93.1415627'),
#  Row(COORDINATES='44.96575731 -93.05016568'),
#  Row(COORDINATES='44.96674348 -93.01049618'),
#  Row(COORDINATES='44.96701855 -93.11083062'),
#  Row(COORDINATES='44.95213391 -93.12121596'),
#  Row(COORDINATES='44.9883057 -93.07114175'),
#  Row(COORDINATES='44.93159317 -93.12455573'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.96657788 -93.13138673'),
#  Row(COORDINATES='44.95271832 -93.02018304'),
#  Row(COORDINATES='44.95211807 -93.15173337'),
#  Row(COORDINATES='44.96663472 -93.07103166'),
#  Row(COORDINATES='44.95212336 -93.1415627'),
#  Row(COORDINATES='44.95213391 -93.12121596'),
#  Row(COORDINATES='44.93296564 -93.13249189'),
#  Row(COORDINATES='44.93296564 -93.13249189'),
#  Row(COORDINATES='44.95307055 -93.19420128'),
#  Row(COORDINATES='44.97378969 -93.11103459'),
#  Row(COORDINATES='44.93296564 -93.13249189'),
#  Row(COORDINATES='44.94501322 -93.19447895'),
#  Row(COORDINATES='44.93677318 -93.0125836'),
#  Row(COORDINATES='44.95212336 -93.1415627'),
#  Row(COORDINATES='44.94501322 -93.19447895'),
#  Row(COORDINATES='44.9809914 -93.10114494'),
#  Row(COORDINATES='44.93164881 -93.1425908'),
#  Row(COORDINATES='44.93777053 -93.14149576'),
#  Row(COORDINATES='44.93677318 -93.0125836'),
#  Row(COORDINATES='44.96656139 -93.02057424'),
#  Row(COORDINATES='44.94501322 -93.19447895'),
#  Row(COORDINATES='44.93677318 -93.0125836'),
#  Row(COORDINATES='44.98097513 -93.11098715'),
#  Row(COORDINATES='44.93164881 -93.1425908'),
#  Row(COORDINATES='44.97378969 -93.11103459'),
#  Row(COORDINATES='44.92939166 -93.01210146'),
#  Row(COORDINATES='44.97381926 -93.10113982'),
#  Row(COORDINATES='44.94501322 -93.19447895'),
#  Row(COORDINATES='44.95307055 -93.19420128'),
#  Row(COORDINATES='44.94481757 -93.01002263'),
#  Row(COORDINATES='44.98115423 -93.05070486'),
#  Row(COORDINATES='44.96656139 -93.02057424'),
#  Row(COORDINATES='44.94481757 -93.01002263'),
#  Row(COORDINATES='44.95307055 -93.19420128'),
#  Row(COORDINATES='44.96007413 -93.19395572'),
#  Row(COORDINATES='44.98115423 -93.05070486'),
#  Row(COORDINATES='44.95916259 -93.07181545'),
#  Row(COORDINATES='44.93079234 -93.08574357'),
#  Row(COORDINATES='44.95211807 -93.15173337'),
#  Row(COORDINATES='44.94501322 -93.19447895'),
#  Row(COORDINATES='44.92939166 -93.01210146'),
#  Row(COORDINATES='44.93079234 -93.08574357'),
#  Row(COORDINATES='44.95936066 -93.14154747'),
#  Row(COORDINATES='44.96671118 -93.10117378'),
#  Row(COORDINATES='44.96667981 -93.06092301'),
#  Row(COORDINATES='44.93901459 -93.122455'),
#  Row(COORDINATES='44.93103211 -93.09519964'),
#  Row(COORDINATES='44.95206541 -93.11116232'),
#  Row(COORDINATES='44.96656139 -93.02057424'),
#  Row(COORDINATES='44.98096117 -93.08248534'),
#  Row(COORDINATES='44.96659439 -93.14154461'),
#  Row(COORDINATES='44.96659439 -93.14154461'),
#  Row(COORDINATES='44.96684449 -93.15174239'),
#  Row(COORDINATES='44.94079035 -93.07635844'),
#  Row(COORDINATES='44.98096815 -93.12118743'),
#  Row(COORDINATES='44.97391713 -93.06089457'),
#  Row(COORDINATES='44.96659439 -93.14154461'),
#  Row(COORDINATES='44.97391713 -93.06089457'),
#  Row(COORDINATES='44.98818129 -93.12107935'),
#  Row(COORDINATES='44.94079035 -93.07635844'),
#  Row(COORDINATES='44.96659439 -93.14154461'),
#  Row(COORDINATES='44.94079035 -93.07635844'),
#  Row(COORDINATES='44.98821439 -93.08263819'),
#  Row(COORDINATES='44.95307055 -93.19420128'),
#  Row(COORDINATES='44.98818129 -93.12107935'),
#  Row(COORDINATES='44.94079035 -93.07635844'),
#  Row(COORDINATES='44.96659439 -93.14154461'),
#  Row(COORDINATES='44.95213391 -93.12121596'),
#  Row(COORDINATES='44.97391713 -93.06089457'),
#  Row(COORDINATES='44.98106675 -93.06120649'),
#  Row(COORDINATES='44.98096117 -93.08248534'),
#  Row(COORDINATES='44.94079035 -93.07635844'),
#  Row(COORDINATES='44.95950658 -93.10207704'),
#  Row(COORDINATES='44.98818129 -93.12107935'),
#  Row(COORDINATES='44.94079035 -93.07635844'),
#  Row(COORDINATES='44.95212336 -93.1415627'),
#  Row(COORDINATES='44.95213391 -93.12121596'),
#  Row(COORDINATES='44.96667981 -93.06092301'),
#  Row(COORDINATES='44.94079035 -93.07635844'),
#  Row(COORDINATES='44.94079035 -93.07635844'),
#  Row(COORDINATES='44.94079035 -93.07635844'),
#  Row(COORDINATES='44.94079035 -93.07635844'),
#  Row(COORDINATES='44.94079035 -93.07635844'),
#  Row(COORDINATES='44.94079035 -93.07635844'),
#  Row(COORDINATES='44.93164881 -93.1425908'),
#  Row(COORDINATES='44.93164881 -93.1425908'),
#  Row(COORDINATES='44.93164881 -93.1425908'),
#  Row(COORDINATES='44.93164881 -93.1425908'),
#  Row(COORDINATES='44.93164881 -93.1425908'),
#  Row(COORDINATES='44.93164881 -93.1425908'),
#  Row(COORDINATES='44.95195822 -93.06126233'),
#  Row(COORDINATES='44.95934727 -93.12122586'),
#  Row(COORDINATES='44.95934727 -93.12122586'),
#  Row(COORDINATES='44.93164881 -93.1425908'),
#  Row(COORDINATES='44.9305755 -93.15171175'),
#  Row(COORDINATES='44.97277532 -93.05082055'),
#  Row(COORDINATES='44.97388818 -93.02023732'),
#  Row(COORDINATES='44.95206541 -93.11116232'),
#  Row(COORDINATES='44.9883057 -93.07114175'),
#  Row(COORDINATES='44.98110238 -93.02019274'),
#  Row(COORDINATES='44.97388818 -93.02023732'),
#  Row(COORDINATES='44.98069554 -93.09262204'),
#  Row(COORDINATES='44.96657788 -93.13138673'),
#  Row(COORDINATES='44.97388818 -93.02023732'),
#  Row(COORDINATES='44.96657788 -93.13138673'),
#  Row(COORDINATES='44.98816169 -93.0605833'),
#  Row(COORDINATES='44.95275049 -93.03135195'),
#  Row(COORDINATES='44.97378009 -93.12120869'),
#  Row(COORDINATES='44.97388818 -93.02023732'),
#  Row(COORDINATES='44.96657788 -93.13138673'),
#  Row(COORDINATES='44.98816169 -93.0605833'),
#  Row(COORDINATES='44.97378969 -93.11103459'),
#  Row(COORDINATES='44.97378009 -93.12120869'),
#  Row(COORDINATES='44.98097513 -93.11098715'),
#  Row(COORDINATES='44.97378969 -93.11103459'),
#  Row(COORDINATES='44.98097513 -93.11098715'),
#  Row(COORDINATES='44.98816169 -93.0605833'),
#  Row(COORDINATES='44.96657788 -93.13138673'),
#  Row(COORDINATES='44.97378969 -93.11103459'),
#  Row(COORDINATES='44.98097513 -93.11098715'),
#  Row(COORDINATES='44.98105556 -93.07106812'),
#  Row(COORDINATES='44.95934727 -93.12122586'),
#  Row(COORDINATES='44.97381926 -93.10113982'),
#  Row(COORDINATES='44.98105556 -93.07106812'),
#  Row(COORDINATES='44.95206015 -93.16189808'),
#  Row(COORDINATES='44.98105556 -93.07106812'),
#  Row(COORDINATES='44.98097513 -93.11098715'),
#  Row(COORDINATES='44.97381926 -93.10113982'),
#  Row(COORDINATES='44.96668989 -93.03039993'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.98097513 -93.11098715'),
#  Row(COORDINATES='44.93787988 -93.17210461'),
#  Row(COORDINATES='44.97381926 -93.10113982'),
#  Row(COORDINATES='44.96668989 -93.03039993'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.9809914 -93.10114494'),
#  Row(COORDINATES='44.94496257 -93.1415298'),
#  Row(COORDINATES='44.96668989 -93.03039993'),
#  Row(COORDINATES='44.98097513 -93.11098715'),
#  Row(COORDINATES='44.96671118 -93.10117378'),
#  Row(COORDINATES='44.95934557 -93.15171272'),
#  Row(COORDINATES='44.95213391 -93.12121596'),
#  Row(COORDINATES='44.9738881 -93.03039075'),
#  Row(COORDINATES='44.9809914 -93.10114494'),
#  Row(COORDINATES='44.98106675 -93.06120649'),
#  Row(COORDINATES='44.95934727 -93.12122586'),
#  Row(COORDINATES='44.95213391 -93.12121596'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.93834266 -93.08555629'),
#  Row(COORDINATES='44.9731164 -93.14113477'),
#  Row(COORDINATES='44.95950658 -93.10207704'),
#  Row(COORDINATES='44.96575731 -93.05016568'),
#  Row(COORDINATES='44.95916259 -93.07181545'),
#  Row(COORDINATES='44.95934727 -93.12122586'),
#  Row(COORDINATES='44.96033456 -93.18220895'),
#  Row(COORDINATES='44.95936066 -93.14154747'),
#  Row(COORDINATES='44.930685 -93.07629816'),
#  Row(COORDINATES='44.96580346 -93.1831301'),
#  Row(COORDINATES='44.96033456 -93.18220895'),
#  Row(COORDINATES='44.98816416 -93.09276252'),
#  Row(COORDINATES='44.95929424 -93.16188682'),
#  Row(COORDINATES='44.96654212 -93.1933639'),
#  Row(COORDINATES='44.97385967 -93.07103595'),
#  Row(COORDINATES='44.96580346 -93.1831301'),
#  Row(COORDINATES='44.96580346 -93.1831301'),
#  Row(COORDINATES='44.96653986 -93.04034004'),
#  Row(COORDINATES='44.96580346 -93.1831301'),
#  Row(COORDINATES='44.96033456 -93.18220895'),
#  Row(COORDINATES='44.96033456 -93.18220895'),
#  Row(COORDINATES='44.95212653 -93.13138291'),
#  Row(COORDINATES='44.95212653 -93.13138291'),
#  Row(COORDINATES='44.94496257 -93.1415298'),
#  Row(COORDINATES='44.96011643 -93.0412236'),
#  Row(COORDINATES='44.97374807 -93.08236551'),
#  Row(COORDINATES='44.95916259 -93.07181545'),
#  Row(COORDINATES='44.98816416 -93.09276252'),
#  Row(COORDINATES='44.94496257 -93.1415298'),
#  Row(COORDINATES='44.98069554 -93.09262204'),
#  Row(COORDINATES='44.98816416 -93.09276252'),
#  Row(COORDINATES='44.95490625 -93.08839557'),
#  Row(COORDINATES='44.95916259 -93.07181545'),
#  Row(COORDINATES='44.96580346 -93.1831301'),
#  Row(COORDINATES='44.97374807 -93.08236551'),
#  Row(COORDINATES='44.98821439 -93.08263819'),
#  Row(COORDINATES='44.97385124 -93.04049766'),
#  Row(COORDINATES='44.96015434 -93.09197852'),
#  Row(COORDINATES='44.96543456 -93.12229417'),
#  Row(COORDINATES='44.97374807 -93.08236551'),
#  Row(COORDINATES='44.97385967 -93.07103595'),
#  Row(COORDINATES='44.98841949 -93.02028833'),
#  Row(COORDINATES='44.95934727 -93.12122586'),
#  Row(COORDINATES='44.9809914 -93.10114494'),
#  Row(COORDINATES='44.98105556 -93.07106812'),
#  Row(COORDINATES='44.98105556 -93.07106812'),
#  Row(COORDINATES='44.95981363 -93.11124934'),
#  Row(COORDINATES='44.95212336 -93.1415627'),
#  Row(COORDINATES='44.98114804 -93.0405584'),
#  Row(COORDINATES='44.96667981 -93.06092301'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.95317796 -93.18263266'),
#  Row(COORDINATES='44.94493121 -93.12116127'),
#  Row(COORDINATES='44.93780462 -93.15170647'),
#  Row(COORDINATES='44.97385967 -93.07103595'),
#  Row(COORDINATES='44.98110238 -93.02019274'),
#  Row(COORDINATES='44.95211807 -93.15173337'),
#  Row(COORDINATES='44.95085149 -93.09573322'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.9161636 -93.18228368'),
#  Row(COORDINATES='44.98105556 -93.07106812'),
#  Row(COORDINATES='44.97388818 -93.02023732'),
#  Row(COORDINATES='44.98115423 -93.05070486'),
#  Row(COORDINATES='44.98115423 -93.05070486'),
#  Row(COORDINATES='44.93834266 -93.08555629'),
#  Row(COORDINATES='44.9592585 -93.17206695'),
#  Row(COORDINATES='44.98096117 -93.08248534'),
#  Row(COORDINATES='44.98821265 -93.10115556'),
#  Row(COORDINATES='44.96673342 -93.0821136'),
#  Row(COORDINATES='44.94342881 -93.10668882'),
#  Row(COORDINATES='44.9592585 -93.17206695'),
#  Row(COORDINATES='44.97381926 -93.10113982'),
#  Row(COORDINATES='44.98106675 -93.06120649'),
#  Row(COORDINATES='44.97391713 -93.06089457'),
#  Row(COORDINATES='44.95934727 -93.12122586'),
#  Row(COORDINATES='44.95203834 -93.17207019'),
#  Row(COORDINATES='44.95934727 -93.12122586'),
#  Row(COORDINATES='44.95203834 -93.17207019'),
#  Row(COORDINATES='44.95212653 -93.13138291'),
#  Row(COORDINATES='44.95934727 -93.12122586'),
#  Row(COORDINATES='44.95212336 -93.1415627'),
#  Row(COORDINATES='44.95991525 -93.02022928'),
#  Row(COORDINATES='44.95186095 -93.07246085'),
#  Row(COORDINATES='44.95490625 -93.08839557'),
#  Row(COORDINATES='44.95934727 -93.12122586'),
#  Row(COORDINATES='44.95213391 -93.12121596'),
#  Row(COORDINATES='44.93103211 -93.09519964'),
#  Row(COORDINATES='44.97385124 -93.04049766'),
#  Row(COORDINATES='44.95266449 -93.01007738'),
#  Row(COORDINATES='44.95934727 -93.12122586'),
#  Row(COORDINATES='44.95206015 -93.16189808'),
#  Row(COORDINATES='44.94493121 -93.12116127'),
#  Row(COORDINATES='44.97353439 -93.09250912'),
#  Row(COORDINATES='44.96656139 -93.02057424'),
#  Row(COORDINATES='44.930685 -93.07629816'),
#  Row(COORDINATES='44.95934727 -93.12122586'),
#  Row(COORDINATES='44.9097727 -93.16035527'),
#  Row(COORDINATES='44.95206541 -93.11116232'),
#  Row(COORDINATES='44.95934557 -93.15171272'),
#  Row(COORDINATES='44.97378969 -93.11103459'),
#  Row(COORDINATES='44.95203834 -93.17207019'),
#  Row(COORDINATES='44.96964098 -93.20235838'),
#  Row(COORDINATES='44.95950658 -93.10207704'),
#  Row(COORDINATES='44.96657788 -93.13138673'),
#  Row(COORDINATES='44.94493121 -93.12116127'),
#  Row(COORDINATES='44.96830023 -93.1195349'),
#  Row(COORDINATES='44.95266449 -93.01007738'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.95987773 -93.06094546'),
#  Row(COORDINATES='44.98069554 -93.09262204'),
#  Row(COORDINATES='44.96663472 -93.07103166'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.98069554 -93.09262204'),
#  Row(COORDINATES='44.95981363 -93.11124934'),
#  Row(COORDINATES='44.9730708 -93.1853462'),
#  Row(COORDINATES='44.96673342 -93.0821136'),
#  Row(COORDINATES='44.95206015 -93.16189808'),
#  Row(COORDINATES='44.96654212 -93.1933639'),
#  Row(COORDINATES='44.96637056 -93.17209931'),
#  Row(COORDINATES='44.98069554 -93.09262204'),
#  Row(COORDINATES='44.95950658 -93.10207704'),
#  Row(COORDINATES='44.93822706 -93.11231687'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.9809914 -93.10114494'),
#  Row(COORDINATES='44.93677318 -93.0125836'),
#  Row(COORDINATES='44.95929424 -93.16188682'),
#  Row(COORDINATES='44.95212653 -93.13138291'),
#  Row(COORDINATES='44.94481757 -93.01002263'),
#  Row(COORDINATES='44.95987773 -93.06094546'),
#  Row(COORDINATES='44.98818129 -93.12107935'),
#  Row(COORDINATES='44.93677318 -93.0125836'),
#  Row(COORDINATES='44.97378969 -93.11103459'),
#  Row(COORDINATES='44.97378969 -93.11103459'),
#  Row(COORDINATES='44.98818129 -93.12107935'),
#  Row(COORDINATES='44.94481757 -93.01002263'),
#  Row(COORDINATES='44.98097513 -93.11098715'),
#  Row(COORDINATES='44.98818129 -93.12107935'),
#  Row(COORDINATES='44.97378969 -93.11103459'),
#  Row(COORDINATES='44.96667981 -93.06092301'),
#  Row(COORDINATES='44.93677318 -93.0125836'),
#  Row(COORDINATES='44.96667981 -93.06092301'),
#  Row(COORDINATES='44.98106675 -93.06120649'),
#  Row(COORDINATES='44.95950658 -93.10207704'),
#  Row(COORDINATES='44.97378969 -93.11103459'),
#  Row(COORDINATES='44.98107913 -93.13106'),
#  Row(COORDINATES='44.97367764 -93.13112479'),
#  Row(COORDINATES='44.97378009 -93.12120869'),
#  Row(COORDINATES='44.91613019 -93.13952579'),
#  Row(COORDINATES='44.97378969 -93.11103459'),
#  Row(COORDINATES='44.91613019 -93.13952579'),
#  Row(COORDINATES='44.97378009 -93.12120869'),
#  Row(COORDINATES='44.98114804 -93.0405584'),
#  Row(COORDINATES='44.916251 -93.15248132'),
#  Row(COORDINATES='44.97378009 -93.12120869'),
#  Row(COORDINATES='44.9731164 -93.14113477'),
#  Row(COORDINATES='44.98821439 -93.08263819'),
#  Row(COORDINATES='44.9731164 -93.14113477'),
#  Row(COORDINATES='44.98096117 -93.08248534'),
#  Row(COORDINATES='44.97378009 -93.12120869'),
#  Row(COORDINATES='44.98069554 -93.09262204'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.98821439 -93.08263819'),
#  Row(COORDINATES='44.98096117 -93.08248534'),
#  Row(COORDINATES='44.95936066 -93.14154747'),
#  Row(COORDINATES='44.93018519 -93.12009175'),
#  Row(COORDINATES='44.93018519 -93.12009175'),
#  Row(COORDINATES='44.96684449 -93.15174239'),
#  Row(COORDINATES='44.98096117 -93.08248534'),
#  Row(COORDINATES='44.93159317 -93.12455573'),
#  Row(COORDINATES='44.93018519 -93.12009175'),
#  Row(COORDINATES='44.96659439 -93.14154461'),
#  Row(COORDINATES='44.94630857 -93.09137717'),
#  Row(COORDINATES='44.96659439 -93.14154461'),
#  Row(COORDINATES='44.93018519 -93.12009175'),
#  Row(COORDINATES='44.93159317 -93.12455573'),
#  Row(COORDINATES='44.98115423 -93.05070486'),
#  Row(COORDINATES='44.96659439 -93.14154461'),
#  Row(COORDINATES='44.93788404 -93.19399087'),
#  Row(COORDINATES='44.93018519 -93.12009175'),
#  Row(COORDINATES='44.93677318 -93.0125836'),
#  Row(COORDINATES='44.98115423 -93.05070486'),
#  Row(COORDINATES='44.94501322 -93.19447895'),
#  Row(COORDINATES='44.93159317 -93.12455573'),
#  Row(COORDINATES='44.93018519 -93.12009175'),
#  Row(COORDINATES='44.96663472 -93.07103166'),
#  Row(COORDINATES='44.93822706 -93.11231687'),
#  Row(COORDINATES='44.94501322 -93.19447895'),
#  Row(COORDINATES='44.93018519 -93.12009175'),
#  Row(COORDINATES='44.98115423 -93.05070486'),
#  Row(COORDINATES='44.93159317 -93.12455573'),
#  Row(COORDINATES='44.92310577 -93.13222901'),
#  Row(COORDINATES='44.94501322 -93.19447895'),
#  Row(COORDINATES='44.96659439 -93.14154461'),
#  Row(COORDINATES='44.93788404 -93.19399087'),
#  Row(COORDINATES='44.96659439 -93.14154461'),
#  Row(COORDINATES='44.95936066 -93.14154747'),
#  Row(COORDINATES='44.93159317 -93.12455573'),
#  Row(COORDINATES='44.95307055 -93.19420128'),
#  Row(COORDINATES='44.96659439 -93.14154461'),
#  Row(COORDINATES='44.95934557 -93.15171272'),
#  Row(COORDINATES='44.98106675 -93.06120649'),
#  Row(COORDINATES='44.96659439 -93.14154461'),
#  Row(COORDINATES='44.91525248 -93.19417847'),
#  Row(COORDINATES='44.96659439 -93.14154461'),
#  Row(COORDINATES='44.95916259 -93.07181545'),
#  Row(COORDINATES='44.95085149 -93.09573322'),
#  Row(COORDINATES='44.96656139 -93.02057424'),
#  Row(COORDINATES='44.92939166 -93.01210146'),
#  Row(COORDINATES='44.95271832 -93.02018304'),
#  Row(COORDINATES='44.95271832 -93.02018304'),
#  Row(COORDINATES='44.92939166 -93.01210146'),
#  Row(COORDINATES='44.95085149 -93.09573322'),
#  Row(COORDINATES='44.97385967 -93.07103595'),
#  Row(COORDINATES='44.95987773 -93.06094546'),
#  Row(COORDINATES='44.95987773 -93.06094546'),
#  Row(COORDINATES='44.95936066 -93.14154747'),
#  Row(COORDINATES='44.95936066 -93.14154747'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.94011645 -93.02768683'),
#  Row(COORDINATES='44.96667981 -93.06092301'),
#  Row(COORDINATES='44.94011645 -93.02768683'),
#  Row(COORDINATES='44.94011645 -93.02768683'),
#  Row(COORDINATES='44.95211807 -93.15173337'),
#  Row(COORDINATES='44.98818129 -93.12107935'),
#  Row(COORDINATES='44.95916259 -93.07181545'),
#  Row(COORDINATES='44.94011645 -93.02768683'),
#  Row(COORDINATES='44.98818129 -93.12107935'),
#  Row(COORDINATES='44.98818129 -93.12107935'),
#  Row(COORDINATES='44.94011645 -93.02768683'),
#  Row(COORDINATES='44.95307055 -93.19420128'),
#  Row(COORDINATES='44.95950658 -93.10207704'),
#  Row(COORDINATES='44.95213391 -93.12121596'),
#  Row(COORDINATES='44.96653986 -93.04034004'),
#  Row(COORDINATES='44.98818129 -93.12107935'),
#  Row(COORDINATES='44.96667981 -93.06092301'),
#  Row(COORDINATES='44.96663472 -93.07103166'),
#  Row(COORDINATES='44.95213391 -93.12121596'),
#  Row(COORDINATES='44.98818129 -93.12107935'),
#  Row(COORDINATES='44.95987773 -93.06094546'),
#  Row(COORDINATES='44.98818129 -93.12107935'),
#  Row(COORDINATES='44.98097513 -93.11098715'),
#  Row(COORDINATES='44.98818129 -93.12107935'),
#  Row(COORDINATES='44.95213391 -93.12121596'),
#  Row(COORDINATES='44.98818129 -93.12107935'),
#  Row(COORDINATES='44.9809914 -93.10114494'),
#  Row(COORDINATES='44.96673342 -93.0821136'),
#  Row(COORDINATES='44.96667981 -93.06092301'),
#  Row(COORDINATES='44.95213391 -93.12121596'),
#  Row(COORDINATES='44.98818129 -93.12107935'),
#  Row(COORDINATES='44.94864046 -93.1021296'),
#  Row(COORDINATES='44.98096815 -93.12118743'),
#  Row(COORDINATES='44.97378969 -93.11103459'),
#  Row(COORDINATES='44.98818129 -93.12107935'),
#  Row(COORDINATES='44.97374807 -93.08236551'),
#  Row(COORDINATES='44.9809914 -93.10114494'),
#  Row(COORDINATES='44.98097513 -93.11098715'),
#  Row(COORDINATES='44.95934727 -93.12122586'),
#  Row(COORDINATES='44.98097513 -93.11098715'),
#  Row(COORDINATES='44.98818129 -93.12107935'),
#  Row(COORDINATES='44.98818129 -93.12107935'),
#  Row(COORDINATES='44.98096117 -93.08248534'),
#  Row(COORDINATES='44.97378969 -93.11103459'),
#  Row(COORDINATES='44.98097513 -93.11098715'),
#  Row(COORDINATES='44.9306653 -93.18229459'),
#  Row(COORDINATES='44.98818129 -93.12107935'),
#  Row(COORDINATES='44.98818129 -93.12107935'),
#  Row(COORDINATES='44.97378969 -93.11103459'),
#  Row(COORDINATES='44.96048735 -93.08086542'),
#  Row(COORDINATES='44.95212336 -93.1415627'),
#  Row(COORDINATES='44.97277532 -93.05082055'),
#  Row(COORDINATES='44.92333514 -93.19397841'),
#  Row(COORDINATES='44.98097513 -93.11098715'),
#  Row(COORDINATES='44.97391713 -93.06089457'),
#  Row(COORDINATES='44.97378969 -93.11103459'),
#  Row(COORDINATES='44.98818129 -93.12107935'),
#  Row(COORDINATES='44.98097513 -93.11098715'),
#  Row(COORDINATES='44.96663472 -93.07103166'),
#  Row(COORDINATES='44.95981363 -93.11124934'),
#  Row(COORDINATES='44.98105556 -93.07106812'),
#  Row(COORDINATES='44.95950658 -93.10207704'),
#  Row(COORDINATES='44.98105556 -93.07106812'),
#  Row(COORDINATES='44.98105556 -93.07106812'),
#  Row(COORDINATES='44.93018519 -93.12009175'),
#  Row(COORDINATES='44.98105556 -93.07106812'),
#  Row(COORDINATES='44.98105556 -93.07106812'),
#  Row(COORDINATES='44.96667981 -93.06092301'),
#  Row(COORDINATES='44.930685 -93.07629816'),
#  Row(COORDINATES='44.95987773 -93.06094546'),
#  Row(COORDINATES='44.9305755 -93.15171175'),
#  Row(COORDINATES='44.98105556 -93.07106812'),
#  Row(COORDINATES='44.98821265 -93.10115556'),
#  Row(COORDINATES='44.930685 -93.07629816'),
#  Row(COORDINATES='44.95490625 -93.08839557'),
#  Row(COORDINATES='44.96637056 -93.17209931'),
#  Row(COORDINATES='44.96580346 -93.1831301'),
#  Row(COORDINATES='44.96667981 -93.06092301'),
#  Row(COORDINATES='44.96580346 -93.1831301'),
#  Row(COORDINATES='44.96033456 -93.18220895'),
#  Row(COORDINATES='44.92310577 -93.13222901'),
#  Row(COORDINATES='44.96654212 -93.1933639'),
#  Row(COORDINATES='44.96033456 -93.18220895'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.96033456 -93.18220895'),
#  Row(COORDINATES='44.96580346 -93.1831301'),
#  Row(COORDINATES='44.96663472 -93.07103166'),
#  Row(COORDINATES='44.930685 -93.07629816'),
#  Row(COORDINATES='44.96580346 -93.1831301'),
#  Row(COORDINATES='44.96033456 -93.18220895'),
#  Row(COORDINATES='44.95317796 -93.18263266'),
#  Row(COORDINATES='44.96580346 -93.1831301'),
#  Row(COORDINATES='44.98114804 -93.0405584'),
#  Row(COORDINATES='44.96580346 -93.1831301'),
#  Row(COORDINATES='44.96580346 -93.1831301'),
#  Row(COORDINATES='44.96671118 -93.10117378'),
#  Row(COORDINATES='44.96580346 -93.1831301'),
#  Row(COORDINATES='44.93159317 -93.12455573'),
#  Row(COORDINATES='44.96663472 -93.07103166'),
#  Row(COORDINATES='44.9592585 -93.17206695'),
#  Row(COORDINATES='44.96575731 -93.05016568'),
#  Row(COORDINATES='44.95213391 -93.12121596'),
#  Row(COORDINATES='44.94630857 -93.09137717'),
#  Row(COORDINATES='44.92310577 -93.13222901'),
#  Row(COORDINATES='44.97385967 -93.07103595'),
#  Row(COORDINATES='44.96580346 -93.1831301'),
#  Row(COORDINATES='44.98115423 -93.05070486'),
#  Row(COORDINATES='44.96580346 -93.1831301'),
#  Row(COORDINATES='44.96033456 -93.18220895'),
#  Row(COORDINATES='44.97381926 -93.10113982'),
#  Row(COORDINATES='44.96580346 -93.1831301'),
#  Row(COORDINATES='44.98110238 -93.02019274'),
#  Row(COORDINATES='44.95987773 -93.06094546'),
#  Row(COORDINATES='44.9592585 -93.17206695'),
#  Row(COORDINATES='44.96580346 -93.1831301'),
#  Row(COORDINATES='44.95987773 -93.06094546'),
#  Row(COORDINATES='44.95950658 -93.10207704'),
#  Row(COORDINATES='44.93834266 -93.08555629'),
#  Row(COORDINATES='44.95211807 -93.15173337'),
#  Row(COORDINATES='44.98105556 -93.07106812'),
#  Row(COORDINATES='44.96575731 -93.05016568'),
#  Row(COORDINATES='44.95212653 -93.13138291'),
#  Row(COORDINATES='44.95987773 -93.06094546'),
#  Row(COORDINATES='44.93787988 -93.17210461'),
#  Row(COORDINATES='44.98106675 -93.06120649'),
#  Row(COORDINATES='44.95490625 -93.08839557'),
#  Row(COORDINATES='44.95212336 -93.1415627'),
#  Row(COORDINATES='44.96015434 -93.09197852'),
#  Row(COORDINATES='44.97374807 -93.08236551'),
#  Row(COORDINATES='44.95916259 -93.07181545'),
#  Row(COORDINATES='44.92442548 -93.11588004'),
#  Row(COORDINATES='44.95987773 -93.06094546'),
#  Row(COORDINATES='44.95212336 -93.1415627'),
#  Row(COORDINATES='44.93834266 -93.08555629'),
#  Row(COORDINATES='44.94987287 -93.08323991'),
#  Row(COORDINATES='44.95266449 -93.01007738'),
#  Row(COORDINATES='44.95934557 -93.15171272'),
#  Row(COORDINATES='44.96543456 -93.12229417'),
#  Row(COORDINATES='44.95936066 -93.14154747'),
#  Row(COORDINATES='44.92376574 -93.10798313'),
#  Row(COORDINATES='44.89857447 -93.16755296'),
#  Row(COORDINATES='44.95212336 -93.1415627'),
#  Row(COORDINATES='44.95916259 -93.07181545'),
#  Row(COORDINATES='44.92294316 -93.08510079'),
#  Row(COORDINATES='44.95212336 -93.1415627'),
#  Row(COORDINATES='44.94496257 -93.1415298'),
#  Row(COORDINATES='44.96641544 -93.0921196'),
#  Row(COORDINATES='44.94493698 -93.13135062'),
#  Row(COORDINATES='44.96671118 -93.10117378'),
#  Row(COORDINATES='44.96011643 -93.0412236'),
#  Row(COORDINATES='44.95186095 -93.07246085'),
#  Row(COORDINATES='44.95212336 -93.1415627'),
#  Row(COORDINATES='44.96701855 -93.11083062'),
#  Row(COORDINATES='44.95936066 -93.14154747'),
#  Row(COORDINATES='44.95273585 -93.0427568'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.95934727 -93.12122586'),
#  Row(COORDINATES='44.96015434 -93.09197852'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.96657788 -93.13138673'),
#  Row(COORDINATES='44.9453393 -93.11134451'),
#  Row(COORDINATES='44.95317796 -93.18263266'),
#  Row(COORDINATES='44.95307055 -93.19420128'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.95307055 -93.19420128'),
#  Row(COORDINATES='44.97378969 -93.11103459'),
#  Row(COORDINATES='44.96671118 -93.10117378'),
#  Row(COORDINATES='44.95307055 -93.19420128'),
#  Row(COORDINATES='44.97378969 -93.11103459'),
#  Row(COORDINATES='44.98115423 -93.05070486'),
#  Row(COORDINATES='44.95307055 -93.19420128'),
#  Row(COORDINATES='44.94501322 -93.19447895'),
#  Row(COORDINATES='44.97378969 -93.11103459'),
#  Row(COORDINATES='44.95307055 -93.19420128'),
#  Row(COORDINATES='44.95307055 -93.19420128'),
#  Row(COORDINATES='44.95307055 -93.19420128'),
#  Row(COORDINATES='44.95271832 -93.02018304'),
#  Row(COORDINATES='44.94501322 -93.19447895'),
#  Row(COORDINATES='44.95307055 -93.19420128'),
#  Row(COORDINATES='44.94501322 -93.19447895'),
#  Row(COORDINATES='44.95307055 -93.19420128'),
#  Row(COORDINATES='44.94501322 -93.19447895'),
#  Row(COORDINATES='44.95307055 -93.19420128'),
#  Row(COORDINATES='44.95307055 -93.19420128'),
#  Row(COORDINATES='44.94501322 -93.19447895'),
#  Row(COORDINATES='44.95307055 -93.19420128'),
#  Row(COORDINATES='44.94501322 -93.19447895'),
#  Row(COORDINATES='44.95307055 -93.19420128'),
#  Row(COORDINATES='44.95307055 -93.19420128'),
#  Row(COORDINATES='44.95307055 -93.19420128'),
#  Row(COORDINATES='44.94501322 -93.19447895'),
#  Row(COORDINATES='44.95307055 -93.19420128'),
#  Row(COORDINATES='44.94501322 -93.19447895'),
#  Row(COORDINATES='44.96015434 -93.09197852'),
#  Row(COORDINATES='44.95307055 -93.19420128'),
#  Row(COORDINATES='44.95085149 -93.09573322'),
#  Row(COORDINATES='44.94987287 -93.08323991'),
#  Row(COORDINATES='44.96659439 -93.14154461'),
#  Row(COORDINATES='44.93901459 -93.122455'),
#  Row(COORDINATES='44.92310577 -93.13222901'),
#  Row(COORDINATES='44.96653986 -93.04034004'),
#  Row(COORDINATES='44.90813495 -93.17187035'),
#  Row(COORDINATES='44.96641544 -93.0921196'),
#  Row(COORDINATES='44.93822706 -93.11231687'),
#  Row(COORDINATES='44.90829928 -93.18134048'),
#  Row(COORDINATES='44.96663472 -93.07103166'),
#  Row(COORDINATES='44.95950658 -93.10207704'),
#  Row(COORDINATES='44.96673342 -93.0821136'),
#  Row(COORDINATES='44.93103211 -93.09519964'),
#  Row(COORDINATES='44.96015434 -93.09197852'),
#  Row(COORDINATES='44.95987773 -93.06094546'),
#  Row(COORDINATES='44.9536711 -93.10112732'),
#  Row(COORDINATES='44.95213391 -93.12121596'),
#  Row(COORDINATES='44.95213391 -93.12121596'),
#  Row(COORDINATES='44.96575731 -93.05016568'),
#  Row(COORDINATES='44.95213391 -93.12121596'),
#  Row(COORDINATES='44.95213391 -93.12121596'),
#  Row(COORDINATES='44.96667981 -93.06092301'),
#  Row(COORDINATES='44.9378441 -93.1619232'),
#  Row(COORDINATES='44.95213391 -93.12121596'),
#  Row(COORDINATES='44.95490625 -93.08839557'),
#  Row(COORDINATES='44.95981363 -93.11124934'),
#  Row(COORDINATES='44.97378969 -93.11103459'),
#  Row(COORDINATES='44.95934727 -93.12122586'),
#  Row(COORDINATES='44.97378969 -93.11103459'),
#  Row(COORDINATES='44.96543456 -93.12229417'),
#  Row(COORDINATES='44.97378009 -93.12120869'),
#  Row(COORDINATES='44.96663472 -93.07103166'),
#  Row(COORDINATES='44.96543456 -93.12229417'),
#  Row(COORDINATES='44.95936066 -93.14154747'),
#  Row(COORDINATES='44.96543456 -93.12229417'),
#  Row(COORDINATES='44.97378009 -93.12120869'),
#  Row(COORDINATES='44.97378009 -93.12120869'),
#  Row(COORDINATES='44.930685 -93.07629816'),
#  Row(COORDINATES='44.98105556 -93.07106812'),
#  Row(COORDINATES='44.96656139 -93.02057424'),
#  Row(COORDINATES='44.98096117 -93.08248534'),
#  Row(COORDINATES='44.97391713 -93.06089457'),
#  Row(COORDINATES='44.94630857 -93.09137717'),
#  Row(COORDINATES='44.98821265 -93.10115556'),
#  Row(COORDINATES='44.97385967 -93.07103595'),
#  Row(COORDINATES='44.92310577 -93.13222901'),
#  Row(COORDINATES='44.96033456 -93.18220895'),
#  Row(COORDINATES='44.97378969 -93.11103459'),
#  Row(COORDINATES='44.96663472 -93.07103166'),
#  Row(COORDINATES='44.96667981 -93.06092301'),
#  Row(COORDINATES='44.96033456 -93.18220895'),
#  Row(COORDINATES='44.95916259 -93.07181545'),
#  Row(COORDINATES='44.95307055 -93.19420128'),
#  Row(COORDINATES='44.96580346 -93.1831301'),
#  Row(COORDINATES='44.9017097 -93.15732289'),
#  Row(COORDINATES='44.94987287 -93.08323991'),
#  Row(COORDINATES='44.96673342 -93.0821136'),
#  Row(COORDINATES='44.96580346 -93.1831301'),
#  Row(COORDINATES='44.95934727 -93.12122586'),
#  Row(COORDINATES='44.96580346 -93.1831301'),
#  Row(COORDINATES='44.95929424 -93.16188682'),
#  Row(COORDINATES='44.97385967 -93.07103595'),
#  Row(COORDINATES='44.98115423 -93.05070486'),
#  Row(COORDINATES='44.95981363 -93.11124934'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.93822706 -93.11231687'),
#  Row(COORDINATES='44.98819579 -93.11092818'),
#  Row(COORDINATES='44.93822706 -93.11231687'),
#  Row(COORDINATES='44.95934727 -93.12122586'),
#  Row(COORDINATES='44.96580346 -93.1831301'),
#  Row(COORDINATES='44.94079035 -93.07635844'),
#  Row(COORDINATES='44.96663472 -93.07103166'),
#  Row(COORDINATES='44.97391713 -93.06089457'),
#  Row(COORDINATES='44.98097513 -93.11098715'),
#  Row(COORDINATES='44.96667981 -93.06092301'),
#  Row(COORDINATES='44.93822706 -93.11231687'),
#  Row(COORDINATES='44.94496257 -93.1415298'),
#  Row(COORDINATES='44.96580346 -93.1831301'),
#  Row(COORDINATES='44.95212336 -93.1415627'),
#  Row(COORDINATES='44.98821265 -93.10115556'),
#  Row(COORDINATES='44.930685 -93.07629816'),
#  Row(COORDINATES='44.95934727 -93.12122586'),
#  Row(COORDINATES='44.95195822 -93.06126233'),
#  Row(COORDINATES='44.96701855 -93.11083062'),
#  Row(COORDINATES='44.9738881 -93.03039075'),
#  Row(COORDINATES='44.95271832 -93.02018304'),
#  Row(COORDINATES='44.96654212 -93.1933639'),
#  Row(COORDINATES='44.95213391 -93.12121596'),
#  Row(COORDINATES='44.96580346 -93.1831301'),
#  Row(COORDINATES='44.96580346 -93.1831301'),
#  Row(COORDINATES='44.96580346 -93.1831301'),
#  Row(COORDINATES='44.95916259 -93.07181545'),
#  Row(COORDINATES='44.96641544 -93.0921196'),
#  Row(COORDINATES='44.95934727 -93.12122586'),
#  Row(COORDINATES='44.97277532 -93.05082055'),
#  Row(COORDINATES='44.93159317 -93.12455573'),
#  Row(COORDINATES='44.96580346 -93.1831301'),
#  Row(COORDINATES='44.98475702 -93.2027105'),
#  Row(COORDINATES='44.95213391 -93.12121596'),
#  Row(COORDINATES='44.95936066 -93.14154747'),
#  Row(COORDINATES='44.95203834 -93.17207019'),
#  Row(COORDINATES='44.95934727 -93.12122586'),
#  Row(COORDINATES='44.9233359 -93.15173555'),
#  Row(COORDINATES='44.95206541 -93.11116232'),
#  Row(COORDINATES='44.95936066 -93.14154747'),
#  Row(COORDINATES='44.91614709 -93.17212624'),
#  Row(COORDINATES='44.95212336 -93.1415627'),
#  Row(COORDINATES='44.96663472 -93.07103166'),
#  Row(COORDINATES='44.94864046 -93.1021296'),
#  Row(COORDINATES='44.96653986 -93.04034004'),
#  Row(COORDINATES='44.95987773 -93.06094546'),
#  Row(COORDINATES='44.96656139 -93.02057424'),
#  Row(COORDINATES='44.97374807 -93.08236551'),
#  Row(COORDINATES='44.98114804 -93.0405584'),
#  Row(COORDINATES='44.95988346 -93.01010391'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.95203834 -93.17207019'),
#  Row(COORDINATES='44.97391713 -93.06089457'),
#  Row(COORDINATES='44.96667981 -93.06092301'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.98096117 -93.08248534'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.93296564 -93.13249189'),
#  Row(COORDINATES='44.97277532 -93.05082055'),
#  Row(COORDINATES='44.94496257 -93.1415298'),
#  Row(COORDINATES='44.96653986 -93.04034004'),
#  Row(COORDINATES='44.95266449 -93.01007738'),
#  Row(COORDINATES='44.95950658 -93.10207704'),
#  Row(COORDINATES='44.95936066 -93.14154747'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.95212653 -93.13138291'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.95212336 -93.1415627'),
#  Row(COORDINATES='44.95936066 -93.14154747'),
#  Row(COORDINATES='44.95212653 -93.13138291'),
#  Row(COORDINATES='44.95934037 -93.13139961'),
#  Row(COORDINATES='44.95950658 -93.10207704'),
#  Row(COORDINATES='44.96015434 -93.09197852'),
#  Row(COORDINATES='44.95981363 -93.11124934'),
#  Row(COORDINATES='44.95981363 -93.11124934'),
#  Row(COORDINATES='44.9809914 -93.10114494'),
#  Row(COORDINATES='44.93777053 -93.14149576'),
#  Row(COORDINATES='44.94864046 -93.1021296'),
#  Row(COORDINATES='44.9536711 -93.10112732'),
#  Row(COORDINATES='44.93822706 -93.11231687'),
#  Row(COORDINATES='44.96015434 -93.09197852'),
#  Row(COORDINATES='44.95490625 -93.08839557'),
#  Row(COORDINATES='44.93834266 -93.08555629'),
#  Row(COORDINATES='44.96653986 -93.04034004'),
#  ...]

# %% [markdown]
# <b>3.4<b/>

# %%
col1 = list(df.columns)
col2 = list(df2.columns)

# %% [markdown]
# We will add the columns of each dataframe to the other dataframe.

# %%
df_new = df
for i in col2:
    df_new = df_new.withColumn(i, lit(None))

# %%
df_new2 = df2
for i in col1:
    df_new2 = df_new2.withColumn(i, lit(None))

# %% [markdown]
# Now we can merge the dataframes.

# %%
merged = df_new.union(df_new2)

# %%
merged.show() #in first 20 rows, all fields added from the 2nd dataset have null values
# Out:
# +------+------+----------+----------+---------+--------------------+-------+-----------+--------------------+--------------+----------------+---------------+-----------------+----------------+
# |   SEX|PRIORS|COMPLEXION|FIOFS_TYPE|TERRORISM|       FIOFS_REASONS|OUTCOME|  RACE_DESC|AGE_AT_FIO_CORRECTED|RACE OF DRIVER|GENDER OF DRIVER|DRIVER FRISKED?|VEHICLE SEARCHED?|CITATION ISSUED?|
# +------+------+----------+----------+---------+--------------------+-------+-----------+--------------------+--------------+----------------+---------------+-----------------+----------------+
# |  MALE|   YES|       Med|      IOFS|       NO|DRUGS, INVESTIGATION|    SFO|   B(Black)|                  59|          null|            null|           null|             null|            null|
# |  MALE|    NO|       Med|        IO|       NO|   DRUGS, POSSESSION|      F|   W(White)|                  26|          null|            null|           null|             null|            null|
# |  MALE|   YES|      Dark|       IOF|       NO| INVESTIGATE, PERSON|      F|   B(Black)|                  18|          null|            null|           null|             null|            null|
# |  MALE|   YES|       Med|      IOFS|       NO|                ABDW|      S|   B(Black)|                  24|          null|            null|           null|             null|            null|
# |  MALE|   YES|     Light|        IO|       NO|                 VAL|      F|   B(Black)|                  70|          null|            null|           null|             null|            null|
# |  MALE|   YES|       Med|       IOF|       NO| INVESTIGATE, PERSON|      F|   B(Black)|                  30|          null|            null|           null|             null|            null|
# |  MALE|    NO|       Med|        IO|       NO|                 VAL|      F|   B(Black)|                  34|          null|            null|           null|             null|            null|
# |  MALE|   YES|     OTHER|        IO|       NO|         DISTURBANCE|      F|   W(White)|                  47|          null|            null|           null|             null|            null|
# |  MALE|   YES|     OTHER|        IO|       NO| INVESTIGATE, PERSON|      F|   W(White)|                  39|          null|            null|           null|             null|            null|
# |  MALE|    NO|     Light|        IO|       NO| INVESTIGATE, PERSON|      F|H(Hispanic)|                  15|          null|            null|           null|             null|            null|
# |  MALE|   YES|       Med|         I|       NO|           209A, A&B|     SF|   W(White)|                  45|          null|            null|           null|             null|            null|
# |  MALE|   YES|       Med|         O|       NO| INVESTIGATE, PERSON|      F|   B(Black)|                  21|          null|            null|           null|             null|            null|
# |  MALE|   YES|      Dark|        OF|       NO|           209A, A&B|     SF|   B(Black)|                  48|          null|            null|           null|             null|            null|
# |  MALE|   YES|       Med|        IO|       NO| INVESTIGATE, PERSON|      F|   B(Black)|                  19|          null|            null|           null|             null|            null|
# |  MALE|   YES|      Dark|        IO|       NO| INVESTIGATE, PERSON|      F|H(Hispanic)|                  45|          null|            null|           null|             null|            null|
# |  MALE|   YES|      Dark|       IOF|       NO| INVESTIGATE, PERSON|      F|   B(Black)|                  18|          null|            null|           null|             null|            null|
# |FEMALE|   YES|     Light|        IO|       NO| INVESTIGATE, PERSON|      F|   W(White)|                  33|          null|            null|           null|             null|            null|
# |  MALE|   YES|     Light|         O|       NO|LARCENY, SHOPLIFTING|      F|H(Hispanic)|                  36|          null|            null|           null|             null|            null|
# |  MALE|   YES|      Dark|        IO|       NO|       ALCOHOL, PARK|      F|   B(Black)|                  28|          null|            null|           null|             null|            null|
# |  MALE|   YES|      Dark|        IF|       NO|INVESTIGATE, PREM...|      S|   B(Black)|                  18|          null|            null|           null|             null|            null|
# +------+------+----------+----------+---------+--------------------+-------+-----------+--------------------+--------------+----------------+---------------+-----------------+----------------+
# only showing top 20 rows

# %% [markdown]
# <b>3.5<b/>

# %%
races = [i["DESCRIPTION"] for i in df.select("DESCRIPTION").distinct().collect()]

# %%
from pyspark.sql.functions import *
for i in races:
    df = df.withColumn("DESCRIPTION", when(df["DESCRIPTION"] == i, i[2:len(i)-1]).otherwise(df["DESCRIPTION"]))

# %%
df.show()
# Out:
# +------+------+-----------+----------+----------+---------+--------------------+-------+--------------------+
# |   SEX|PRIORS|DESCRIPTION|COMPLEXION|FIOFS_TYPE|TERRORISM|       FIOFS_REASONS|OUTCOME|AGE_AT_FIO_CORRECTED|
# +------+------+-----------+----------+----------+---------+--------------------+-------+--------------------+
# |  MALE|   YES|      Black|       Med|      IOFS|       NO|DRUGS, INVESTIGATION|    SFO|                  59|
# |  MALE|    NO|      White|       Med|        IO|       NO|   DRUGS, POSSESSION|      F|                  26|
# |  MALE|   YES|      Black|      Dark|       IOF|       NO| INVESTIGATE, PERSON|      F|                  18|
# |  MALE|   YES|      Black|       Med|      IOFS|       NO|                ABDW|      S|                  24|
# |  MALE|   YES|      Black|     Light|        IO|       NO|                 VAL|      F|                  70|
# |  MALE|   YES|      Black|       Med|       IOF|       NO| INVESTIGATE, PERSON|      F|                  30|
# |  MALE|    NO|      Black|       Med|        IO|       NO|                 VAL|      F|                  34|
# |  MALE|   YES|      White|     OTHER|        IO|       NO|         DISTURBANCE|      F|                  47|
# |  MALE|   YES|      White|     OTHER|        IO|       NO| INVESTIGATE, PERSON|      F|                  39|
# |  MALE|    NO|   Hispanic|     Light|        IO|       NO| INVESTIGATE, PERSON|      F|                  15|
# |  MALE|   YES|      White|       Med|         I|       NO|           209A, A&B|     SF|                  45|
# |  MALE|   YES|      Black|       Med|         O|       NO| INVESTIGATE, PERSON|      F|                  21|
# |  MALE|   YES|      Black|      Dark|        OF|       NO|           209A, A&B|     SF|                  48|
# |  MALE|   YES|      Black|       Med|        IO|       NO| INVESTIGATE, PERSON|      F|                  19|
# |  MALE|   YES|   Hispanic|      Dark|        IO|       NO| INVESTIGATE, PERSON|      F|                  45|
# |  MALE|   YES|      Black|      Dark|       IOF|       NO| INVESTIGATE, PERSON|      F|                  18|
# |FEMALE|   YES|      White|     Light|        IO|       NO| INVESTIGATE, PERSON|      F|                  33|
# |  MALE|   YES|   Hispanic|     Light|         O|       NO|LARCENY, SHOPLIFTING|      F|                  36|
# |  MALE|   YES|      Black|      Dark|        IO|       NO|       ALCOHOL, PARK|      F|                  28|
# |  MALE|   YES|      Black|      Dark|        IF|       NO|INVESTIGATE, PREM...|      S|                  18|
# +------+------+-----------+----------+----------+---------+--------------------+-------+--------------------+
# only showing top 20 rows

# %%
df.write.csv("Police Interviews(S3).csv")

# %%
df2.write.csv("Vehicle Stops(S3).csv")
